# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import argparse
import time
import sys
import imageio
from IPython import display

# %%
# For each problem size, we want to go through the Static data that was
# collected for each of the policies. 
# This static data will allow us to create an oracle that knows the best
# policy for each region+feature+idx combination.

# Set some plotting params
plt.rcParams['figure.figsize'] = [12, 5]
plt.rcParams['figure.dpi'] = 100

# %%
# Let's first read in all our desired files.

# Go to the rundata dir
run_data_dir='/g/g15/bolet1/workspace/lulesh-region-fix-correct/LULESH/runData/'
os.chdir(run_data_dir)
# !pwd

# Next, let's gather up our targets
# It's all the TRACE_CSV data from each of the static runs
# There was only one invocation of each static run, so in the future
# we might want to make an oracle that takes an average of all the repeat
# executions
csvs = list(glob.glob("VA_RegionMod_explrStatic,*/trace-lulesh-VA_RegionMod_explrStatic*/*.csv"))
csvs.sort()
print(len(csvs))
print(csvs)
# Out:
# /usr/WS2/bolet1/lulesh-region-fix-correct/LULESH/runData
# 252
# ['VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1128-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1211-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1253-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1292-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1317-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1351-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1384-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1722-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1806-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1849-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2011-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2286-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2296-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2338-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2360-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2388-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2413-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2459-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2503-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2565-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2623-rank-0.csv', 'VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_R ...

# %%
# Because each of the files has the policy within the 'training' column
# and the region name in the 'region' column, we only need to add the 'runsize'
# column to tell the run sizes apart
def load_my_csv(csvfile):
    # Load the SingleMod Dataset
    print('Loading file:', csvfile)
    filename = csvfile[:-4]
    t = time.perf_counter()
    df = pd.read_csv(csvfile, sep=' ')
    elapsed_time = time.perf_counter() - t
    print('Read in CSV file in', int(elapsed_time), 'second(s)')
    print('Data shape: ', df.shape)
    
    # Drop rankid column, rankid is constant
    df = df.drop(['rankid'], 1)
    
    # Extract the runsize from the file path string
    target = 'trainSize'
    targetLoc = csvfile.find(target) + len(target)
    
    df['runsize'] = int(csvfile[targetLoc:targetLoc+2])
    
    return df

# %%
df = pd.DataFrame()
t = time.perf_counter()

# Read all the CSV files
for idx, csvfile in enumerate(csvs):
    print('On file', idx+1, 'of', len(csvs))
    csvdf = load_my_csv(csvfile)
    df = df.append(csvdf)
    
elapsed_time = time.perf_counter() - t
print('Read in ALL CSV files in', int(elapsed_time), 'second(s)')

print('Done loading all CSVs')
print(df.shape)
print(df.size)
# Out:
# On file 1 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1128-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 2 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1211-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 3 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1253-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 4 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1292-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 5 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1317-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 9)
# On file 6 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1351-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 7 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1384-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 8 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1722-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 9 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1806-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 10 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l1849-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 11 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2011-rank-0.csv
# /usr/tce/packages/python/python-3.7.2/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Read in CSV file in 0 second(s)
# Data shape:  (92268, 7)
# On file 12 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2286-rank-0.csv
# Read in CSV file in 3 second(s)
# Data shape:  (2530380, 7)
# On file 13 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2296-rank-0.csv
# Read in CSV file in 3 second(s)
# Data shape:  (2530380, 7)
# On file 14 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2338-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (843460, 7)
# On file 15 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2360-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (843460, 7)
# On file 16 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2388-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (843460, 7)
# On file 17 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2413-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (843460, 7)
# On file 18 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2459-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (843460, 7)
# On file 19 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2503-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (93200, 7)
# On file 20 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2565-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (843460, 11)
# On file 21 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2623-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (93200, 7)
# On file 22 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2675-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 10)
# On file 23 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2758-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 24 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2817-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (93200, 7)
# On file 25 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l2905-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (93200, 7)
# On file 26 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l304-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 7)
# On file 27 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l570-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 8)
# On file 28 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize30/trace-Static,0-region-lulesh.cc.apollo.region.l871-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (932, 8)
# On file 29 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1128-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 30 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1211-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 31 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1253-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 32 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1292-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 33 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1317-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 9)
# On file 34 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1351-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 35 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1384-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 36 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1722-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 37 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1806-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 38 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l1849-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 39 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2011-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (100000, 7)
# On file 40 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2286-rank-0.csv
# Read in CSV file in 3 second(s)
# Data shape:  (2715000, 7)
# On file 41 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2296-rank-0.csv
# Read in CSV file in 3 second(s)
# Data shape:  (2715000, 7)
# On file 42 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2338-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (905000, 7)
# On file 43 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2360-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (905000, 7)
# On file 44 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2388-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (905000, 7)
# On file 45 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2413-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (905000, 7)
# On file 46 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2459-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (905000, 7)
# On file 47 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2503-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (100000, 7)
# On file 48 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2565-rank-0.csv
# Read in CSV file in 1 second(s)
# Data shape:  (905000, 11)
# On file 49 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2623-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (100000, 7)
# On file 50 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2675-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 10)
# On file 51 of 252
# Loading file: VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-lulesh-VA_RegionMod_explrStatic,0_c8_pol3_depth4_trainSize55/trace-Static,0-region-lulesh.cc.apollo.region.l2758-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file
rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (100000, 7)
# On file 246 of 252
# Loading file: VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-lulesh-VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-Static,2-region-lulesh.cc.apollo.region.l2675-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 10)
# On file 247 of 252
# Loading file: VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-lulesh-VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-Static,2-region-lulesh.cc.apollo.region.l2758-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 248 of 252
# Loading file: VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-lulesh-VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-Static,2-region-lulesh.cc.apollo.region.l2817-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (100000, 7)
# On file 249 of 252
# Loading file: VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-lulesh-VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-Static,2-region-lulesh.cc.apollo.region.l2905-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (100000, 7)
# On file 250 of 252
# Loading file: VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-lulesh-VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-Static,2-region-lulesh.cc.apollo.region.l304-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 7)
# On file 251 of 252
# Loading file: VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-lulesh-VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-Static,2-region-lulesh.cc.apollo.region.l570-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 8)
# On file 252 of 252
# Loading file: VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-lulesh-VA_RegionMod_explrStatic,2_c8_pol3_depth4_trainSize80/trace-Static,2-region-lulesh.cc.apollo.region.l871-rank-0.csv
# Read in CSV file in 0 second(s)
# Data shape:  (1000, 8)
# Read in ALL CSV files in 4657 second(s)
# Done loading all CSVs
# (100051704, 11)
# 1100568744

# %%
df.head()

# Some features will be missing, fill them in with a -1
df = df.fillna(-1)

# %%
# Now that we have all our data together, let's make the oracle
# for each of the runSizes in {30, 55, 80}

t = time.perf_counter()

oracle30 = df.loc[df['runsize'] == 30]
oracle55 = df.loc[df['runsize'] == 55]
oracle80 = df.loc[df['runsize'] == 80]

elapsed_time = time.perf_counter() - t
print('Subset oracles in', int(elapsed_time), 'second(s)')
# Out:
# Subset oracles in 11 second(s)

# %%
# For each region+idx combination, we want to grab the minimum time.
# This will then correspond to an optimal policy for the given execution.
# The region+idx combo is equivalent to the region+feature_vector+idx combo

t = time.perf_counter()

# Here we sort by xtime, drop any duplicate region/idx combinations
# then reset the index to be by region/idx combos
oracle30 = oracle30.sort_values(by=['xtime'])\
                   .drop_duplicates(['region', 'idx'], keep='first')\
                   .set_index(['region', 'idx'])\
                   .sort_index()

oracle55 = oracle55.sort_values(by=['xtime'])\
                   .drop_duplicates(['region', 'idx'], keep='first')\
                   .set_index(['region', 'idx'])\
                   .sort_index()

oracle80 = oracle80.sort_values(by=['xtime'])\
                   .drop_duplicates(['region', 'idx'], keep='first')\
                   .set_index(['region', 'idx'])\
                   .sort_index()

elapsed_time = time.perf_counter() - t
print('Made complete oracles in', int(elapsed_time), 'second(s)')
# Out:
# Made complete oracles in 158 second(s)

# %%
# Now that we have our oracle datasets, let's save them
t = time.perf_counter()

outputcsv_dir='/g/g15/bolet1/workspace/lulesh-region-fix-correct/LULESH/preprocData/'

oracle30.to_csv(outputcsv_dir+'oracle30.csv', index=True, sep=' ')
print(oracle30.shape)

oracle55.to_csv(outputcsv_dir+'oracle55.csv', index=True, sep=' ')
print(oracle55.shape)

oracle80.to_csv(outputcsv_dir+'oracle80.csv', index=True, sep=' ')
print(oracle80.shape)

elapsed_time = time.perf_counter() - t
print('Saved oracles in', int(elapsed_time), 'second(s)')
# Out:
# (10600568, 9)
# (11375000, 9)
# (11375000, 9)
# Saved oracles in 8257 second(s)

# %%
# Returns the amount of memory in MB that the df uses
def dfMemUsage(df):
    return df.memory_usage(index=True).sum()/(1024*1024)

# %%
print('Oracle 30 uses', dfMemUsage(oracle30), 'MB of space')
print('Oracle 55 uses', dfMemUsage(oracle55), 'MB of space')
print('Oracle 80 uses', dfMemUsage(oracle80), 'MB of space')
# Out:
# Oracle 30 uses 797.7362699508667 MB of space
# Oracle 55 uses 856.0136137008667 MB of space
# Oracle 80 uses 856.0136137008667 MB of space
